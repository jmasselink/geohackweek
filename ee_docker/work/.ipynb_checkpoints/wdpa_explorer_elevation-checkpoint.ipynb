# %% [markdown]
# ### From JavaScript here: https://code.earthengine.google.com/5806d067c03a964285f573ad61f07639

# %%
import ee, pandas #geopandas / shapely not in current environment - docker container
from IPython import display ##used to display images
from matplotlib import pyplot
# from IPython.display import Image
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-8-9948ae93c316> in <module>()
# ----> 1 import ee, pandas, shapely #geopandas
#       2 from IPython import display ##used to display images
#       3 from matplotlib import pyplot
#       4 # from IPython.display import Image
#
# ImportError: No module named shapely

# %%
ee.Initialize()

# %%
das_sites = ee.FeatureCollection('users/jmasselink/das_sites') ##//ft:1NJIeeE0BzZLNtqA3-WSyxzGg2jxg59K4zD249QCv')

# %%
print(das_sites) ##.info())
# Out:
# ee.FeatureCollection({
#   "type": "Invocation",
#   "arguments": {
#     "tableId": "users/jmasselink/das_sites"
#   },
#   "functionName": "Collection.loadTable"
# })

# %%
# from matplotlib import rcsetup
# rcsetup.all_backends

# %% [markdown]
# #### Accessing Feature Class parameters

# %%
## This takes too long - don't do it.
# print(das_sites.getInfo())
count = das_sites.size()
fcDict = das_sites.toDictionary() ##version()
print(count) ## + (fcType))
print(fcDict)
# Out:
# ee.Number({
#   "type": "Invocation",
#   "arguments": {
#     "collection": {
#       "type": "Invocation",
#       "arguments": {
#         "tableId": "users/jmasselink/das_sites"
#       },
#       "functionName": "Collection.loadTable"
#     }
#   },
#   "functionName": "Collection.size"
# })
# ee.Dictionary({
#   "type": "Invocation",
#   "arguments": {
#     "element": {
#       "type": "Invocation",
#       "arguments": {
#         "tableId": "users/jmasselink/das_sites"
#       },
#       "functionName": "Collection.loadTable"
#     }
#   },
#   "functionName": "Element.toDictionary"
# })

# %%
list_sites = das_sites.aggregate_count("columns") ##="name")  ##aggregate_array
print(list_sites)
# Out:
# ee.ComputedObject({
#   "type": "Invocation",
#   "arguments": {
#     "property": "columns",
#     "collection": {
#       "type": "Invocation",
#       "arguments": {
#         "tableId": "users/jmasselink/das_sites"
#       },
#       "functionName": "Collection.loadTable"
#     }
#   },
#   "functionName": "AggregateFeatureCollection.count"
# })

# %%
list_sites = das_sites.aggregate_count("name")  ##aggregate_array
print(list_sites)
# Out:
# ee.ComputedObject({
#   "type": "Invocation",
#   "arguments": {
#     "property": "name",
#     "collection": {
#       "type": "Invocation",
#       "arguments": {
#         "tableId": "users/jmasselink/das_sites"
#       },
#       "functionName": "Collection.loadTable"
#     }
#   },
#   "functionName": "AggregateFeatureCollection.count"
# })

# %% [markdown]
# #### Query for a name

# %%
## (ee.FeatureCollection('ft:1fRY18cjsHzDgGiJiS2nnpUU3v9JPDc2HNaR7Xk8')
fcLewa = (das_sites.filter(ee.Filter().eq('name', 'Lewa')))

infoLewa = fcLewa.getInfo()
print(infoLewa)
# Out:
# %% [markdown]
# ## Load asset Feature Collection
# Head back to the [Earth Engine Public Data Catalog](https://earthengine.google.org/#index), search for **SRTM**, and load up the data description page for the **SRTM** dataset. The ID for this Image Collection is **CGIAR/SRTM90_V4**.

# %%
srtm = ee.Image('CGIAR/SRTM90_V4')
Image(url=srtm.getThumbUrl())
# Out:
# <img src="https://earthengine.googleapis.com/api/thumb?thumbid=085f265c2d1272f20c9af0b75285862f&token=d75984c113dbc4d091df89f91f445c17"/>

# %%
Image(url=srtm.getThumbUrl({'min':0, 'max':3000}))
# Out:
# <img src="https://earthengine.googleapis.com/api/thumb?thumbid=07e3a3e3d10f81a87f0a11b00dd61b70&token=1b683f78147c11d258a8893770e65739"/>

# %%
hillshade = ee.Terrain.hillshade(srtm) #.visualize(forceRgbOutput=True)

# %%
hillshade.getInfo()
# Out:
# {u'bands': [{u'crs': u'EPSG:4326',
#    u'crs_transform': [0.000833333333333,
#     0.0,
#     -180.0,
#     0.0,
#     -0.000833333333333,
#     60.0],
#    u'data_type': {u'max': 255,
#     u'min': 0,
#     u'precision': u'int',
#     u'type': u'PixelType'},
#    u'id': u'hillshade'}],
#  u'type': u'Image'}

# %%
Image(url=hillshade.getThumbUrl())
# Out:
# <img src="https://earthengine.googleapis.com/api/thumb?thumbid=1efdc4e9d9fef350b566a39528b527fd&token=6708edfdcb7857148a8b3b6975908da5"/>

# %%
Image(url=hillshade.getThumbUrl({'hillshade': hillshade}))
# Out:
# <img src="https://earthengine.googleapis.com/api/thumb?thumbid=1efdc4e9d9fef350b566a39528b527fd&token=9eb6d3e47ad464fa6bdaccc107150cfb"/>

# %%
# allregion = das_sites.geometry().bounds()
allregion = ee.Geometry.Polygon([-170, 80, 0, 80, 170, 80, 170, -80, 10, -80, -170, -80], None, False)

# %%
def print_image(image,region):
  display.display(display.Image(ee.data.getThumbnail({
      'image': image.serialize(),
      'dimensions': 500,
      'region':region
})))

# %%
print_image(srtm, allregion)
# Out:
# EEExceptionTraceback (most recent call last)
# <ipython-input-65-1026bda15abe> in <module>()
# ----> 1 print_image(srtm, allregion)
#
# <ipython-input-64-27bb289e957d> in print_image(image, region)
#       3       'image': image.serialize(),
#       4       'dimensions': 500,
# ----> 5       'region':region
#       6 })))
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/ee/data.pyc in getThumbnail(params)
#     258     A thumbnail image as raw PNG data.
#     259   """
# --> 260   return send_('/thumb', params, opt_method='GET', opt_raw=True)
#     261
#     262
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/ee/data.pyc in send_(path, params, opt_method, opt_raw)
#     738     # error above rather than this generic one.
#     739     raise ee_exception.EEException('Server returned HTTP code: %d' %
# --> 740                                    response.status)
#     741
#     742   # Now known not to be an error response...
#
# EEException: Server returned HTTP code: 400

# %%
### Create the ele tracks layer
empty1 = ee.Image().byte()
painted=empty1.paint(featureCollection=eleTrack,
  color=1,
  width=5).visualize(palette=['FF0000'],forceRgbOutput=True)

# %%
# ### Create image collection from layers and mosaic in desired draw order
outImg = ee.ImageCollection([hillshade,painted]).mosaic()
# print(outImg.getThumbURL()) #getting the unbounded error here ()
print(outImg.getThumbURL("region": allregion))

# %%
print_image(outImg,allregion) #getting http 400 error here
